# %%
import pandas as pd

df = pd.read_csv('../sentences/01-01-23.csv', header=None)
df
# Out:
#                                                       0
# 0                      \nlive\nDuniani Leo Video Tube\n
# 1     \nMeli iliyokuwa na wahamiaji wasiopungua 700 ...
# 2     \nRonaldo atajwa kuweka historia nyingine kati...
# 3     \nUingereza yasema Russia inatarajiwa kuendele...
# 4     \nWatu wanane wapoteza Maisha katika maporomok...
# ...                                                 ...
# 5157                            \nUchaguzi Kenya 2017\n
# 5158                 \nRipoti Maalum Ajali Barabarani\n
# 5159                           \nUchaguzi Uganda 2016\n
# 5160         \nKundi la viongozi vijane Afrika - YALI\n
# 5161         \nZiara ya Rais Obama Kenya, Julai 23-26\n
#
# [5162 rows x 1 columns]

# %%
import re

noise_words = [
    "Facebook Forum", "live\nDuniani Leo Video Tube", "Duniani Leo", "Forum",
    "Please enable JavaScript to view the", "comments powered by Disqus.", "Embed",
    "share", "The code has been copied to your clipboard.",
    "The URL has been copied to your clipboard", "Shirikiana kwenye Facebook",
    "Shirikiana kwenye Twitter", "No media source currently available",
    "0:00", "0:03:06", "Kiungo cha moja kwa moja", "16 kbps | MP3",
    "32 kbps | MP3", "48 kbps | MP3", "Pleya", "by VOA Swahili - Idhaa ya Kiswahili ya Sauti ya Amerika",
    "VOA Express"
]

pattern = re.compile('|'.join([re.escape(word) for word in noise_words]), re.IGNORECASE)
text = pattern.sub('', str(df))
text = text.replace('\n', ' ').replace('\r', ' ')
text = re.sub(r'\s+', ' ', text)
text.strip()
print(text)
# Out:
#  0 0 \nlive\n Video Tube\n 1 \nMeli iliyokuwa na wahamiaji wasiopungua 700 ... 2 \nRonaldo atajwa kuweka historia nyingine kati... 3 \nUingereza yasema Russia inatarajiwa kuendele... 4 \nWatu wanane wapoteza Maisha katika maporomok... ... ... 5157 \nUchaguzi Kenya 2017\n 5158 \nRipoti Maalum Ajali Barabarani\n 5159 \nUchaguzi Uganda 2016\n 5160 \nKundi la viongozi vijane Afrika - YALI\n 5161 \nZiara ya Rais Obama Kenya, Julai 23-26\n [5162 rows x 1 columns]

# %%
# Out:
# '                                                      0\n0                      \\nlive\\n Video Tube\\n\n1     \\nMeli iliyokuwa na wahamiaji wasiopungua 700 ...\n2     \\nRonaldo atajwa kuweka historia nyingine kati...\n3     \\nUingereza yasema Russia inatarajiwa kuendele...\n4     \\nWatu wanane wapoteza Maisha katika maporomok...\n...                                                 ...\n5157                            \\nUchaguzi Kenya 2017\\n\n5158                 \\nRipoti Maalum Ajali Barabarani\\n\n5159                           \\nUchaguzi Uganda 2016\\n\n5160         \\nKundi la viongozi vijane Afrika - YALI\\n\n5161         \\nZiara ya Rais Obama Kenya, Julai 23-26\\n\n\n[5162 rows x 1 columns]'
